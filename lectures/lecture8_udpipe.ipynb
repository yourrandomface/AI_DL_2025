# %%
import pandas as pd

# %%
df = pd.read_excel('/content/drive/MyDrive/ML ITHUB осень/ДИ 2024/IT-СИП-22-23-DATA-ML/data/Копия файла "vacancies.xlsx"')
df.head()
# Out:
#                                             title  \
# 0                         Программист C# (Senior)
# 1                          Начинающий программист
# 2                          Начинающий программист
# 3                        Инженер - программист 1С
# 4  Программист кастомной конфигурации 1С (Middle)
#
#                                          description  real_salary
# 0  Agile. Azure DevOps (build server, task tracke...      97500.0
# 1  Работаем с реляционными БД, поэтому желательно...      50000.0
# 2  Работаем с реляционными БД, поэтому желательно...      50000.0
# 3  Опыт работы с конфигурацией 1С ERP2 и знание о...      70000.0
# 4     Поддержка управленческой самописной БД в 18...     120000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2706 entries, 0 to 2705
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        2706 non-null   object
#  1   description  2706 non-null   object
#  2   real_salary  2706 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 63.5+ KB

# %%
df['description'].values[:10]
# Out:
# array(['Agile. Azure DevOps (build server, task tracker, git repo, documentation, web hooks). Git + git flow. .NET Framework 4.5... Разработка и доработка ключевых продуктов и сервисов. Решение наиболее сложных и ответственных задач. Активное участие в планировании работы команды. ',
#        'Работаем с реляционными БД, поэтому желательно понимание принципов их работы и умение оптимизировать логику обработки данных – SQL, MySQL, PostgreSQL.  ...доработка интерфейсной части и отчетных форм, внесение изменений в бизнес-логику, реализация модулей для взаимодействия с внешними системами. ',
#        'Работаем с реляционными БД, поэтому желательно понимание принципов их работы и умение оптимизировать логику обработки данных – SQL, MySQL, PostgreSQL.  ...доработка интерфейсной части и отчетных форм, внесение изменений в бизнес-логику, реализация модулей для взаимодействия с внешними системами. ',
#        'Опыт работы с конфигурацией 1С ERP2 и знание основ бухгалтерского учета приветствуется. Опыт работы в должности инженера-программиста... Сопровождение 1С УПП. Разработка нового функционала 1С УПП. Консультация пользователей. Участие во внедрении 1С ERP. ',
#        '   Поддержка управленческой самописной БД в 18 ТБ; Поддержка обмена между головным и дочерним узлом 2 млн объектов в сутки; Ежедневые автоматические обновления конфигурации; Написание сервисов по работе с системным и сетевым оборудованием. Участие в незаурядных проектах автоматизации на платформе 1С; Создание и доработка решений по готовым техническим заданиям; Участие в развитии существующей ИТ-инфраструктуры компании. Опыт работы 1-3 года; Хорошее понимание платформы 1С 8.3; Знание и умение работать с основными объектами платформы; Понимание клиент-серверного взаимодействия 1С. Умение оптимизации запросов; Понимание связи объектов 1С и физического их расположение в БД; Опыт выборки данных и изменения на SQL; Работа со средствами интеграции на 1С (сервисы, обмены…). Высоконагруженные и геораспределенные системы, которые гарантируют сложные и интересные задачи Отсутствие бюрократии, возможность вносить свой вклад и непосредственно влиять на итоговые решения Профессиональный рост — возможность развиваться как руководитель или эксперт Грамотно выстроенные процессы работы Командный подход к разработке Поощрение обмена знаниями и опытом Трудоустройство по ТК РФ в официально зарегистрированной ИТ-компании и полностью “белую” заработную плату Ежегодную премию по результатам работы Компании Прозрачную систему грейдов для роста внутри компании Компенсацию обучения по профилю 70% Возможность приобретать товары Компании по специальной цене Скидки на обучение английскому языку и скидки от партнёров (фитнес-клуб, мобильная связь) Участие в технических конференциях и корпоративных мероприятиях Офис, оснащенный всей необходимой техникой для работы, а также местом для отдыха и кухней. Как дополнительный плюс – наличие парковки Возможность найти коллег по интересам для участия в различных внерабочих активностях 1С программирование MS SQL',
#        'Умение разбираться в поставленных задачах, уточнять их условия и результат, выбирать эффективные способы решения. Понимание ООП и паттернов проектирования, следование... Мы работаем над предоставлением нашим клиентам целого комплекса IT-решений, начиная с e-commerce и заканчивая digital-трансформацией традиционной розницы. ',
#        'Уверенные знания и опыт разработки/доработки отчетов с использованием механизмов системы компоновки данных 1С:ERP, 1С:УПП, 1... Доработка нетиповой конфигурации 1С: УПП. Создание внешних отчетов, обработок, печатных форм. Обновление нетиповой конфигурации 1С.',
#        'Наличие знаний PHP и/или Javascript (мы не обучаем "с нуля"). Умение быстро усваивать материал. Ответственное отношение к работе.  Веб-разработка. Прохождение обучающих курсов. Сдача экзамена.',
#        'Умение разбираться в чужом коде. Практический опыт разработки на 1С 8 от 3 лет и выше. Знание и опыт... Программирование и доработка конфигурации Управление торговлей 11.4. Доработка функционала конфигурации Управление Торговлей. Обновление не типовых конфигураций. Настройка обменов. ',
#        '   Поддержка управленческой самописной БД в 18 ТБ; Поддержка обмена между головным и дочерним узлом 2 млн объектов в сутки; Ежедневые автоматические обновления конфигурации; Написание сервисов по работе с системным и сетевым оборудованием. Участие в незаурядных проектах автоматизации на платформе 1С; Создание и доработка решений по готовым техническим заданиям; Участие в развитии существующей ИТ-инфраструктуры компании. Опыт работы 3 года; Хорошее понимание платформы 1С 8.3; Знание и умение работать с основными объектами платформы; Понимание клиент-серверного взаимодействия 1С; Умение оптимизировать запросы; Понимание связи объектов 1С и физического их расположение в БД; Опыт выборки данных и изменения на SQL; Работа со средствами интеграции на 1С (сервисы, обмены…). Высоконагруженные и геораспределенные системы, которые гарантируют сложные и интересные задачи Отсутствие бюрократии, возможность вносить свой вклад и непосредственно влиять на итоговые решения Профессиональный рост — возможность развиваться как руководитель или эксперт Грамотно выстроенные процессы работы Командный подход к разработке Поощрение обмена знаниями и опытом Трудоустройство по ТК РФ в официально зарегистрированной ИТ-компании и полностью “белую” заработную плату Ежегодную премию по результатам работы Компании Прозрачную систему грейдов для роста внутри компании Компенсацию обучения по профилю 70% Возможность приобретать товары Компании по специальной цене Скидки на обучение английскому языку и скидки от партнёров (фитнес-клуб, мобильная связь) Участие в технических конференциях и корпоративных мероприятиях Офис, оснащенный всей необходимой техникой для работы, а также местом для отдыха и кухней. Как дополнительный плюс – наличие парковки Возможность найти коллег по интересам для участия в различных внерабочих активностях 1С программирование MS SQL'],
#       dtype=object)

# %%
df.drop_duplicates(keep='first',inplace=True)
df.head()
# Out:
#                                             title  \
# 0                         Программист C# (Senior)
# 1                          Начинающий программист
# 3                        Инженер - программист 1С
# 4  Программист кастомной конфигурации 1С (Middle)
# 5                       Fullstack web-программист
#
#                                          description  real_salary
# 0  Agile. Azure DevOps (build server, task tracke...      97500.0
# 1  Работаем с реляционными БД, поэтому желательно...      50000.0
# 3  Опыт работы с конфигурацией 1С ERP2 и знание о...      70000.0
# 4     Поддержка управленческой самописной БД в 18...     120000.0
# 5  Умение разбираться в поставленных задачах, уто...     165000.0

# %% [markdown]
# Задачей синтаксического анализа является определение связей между словами. Результатом синтаксического анализа является дерево одного из двух видов - дерево зависимостей или дерево составляющих. Дерево зависимостей показывает связи между отдельными словами, дерево составляющих показывает как слова складываются в группы. Так как дерево зависимостей содержит больше информации, мы будем использовать именно этот формализм.

# %%
# !pip install ufal.udpipe
# Out:
# Collecting ufal.udpipe
#   Downloading ufal.udpipe-1.3.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Downloading ufal.udpipe-1.3.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (936 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 936.8/936.8 kB 17.9 MB/s eta 0:00:00
# Installing collected packages: ufal.udpipe
# Successfully installed ufal.udpipe-1.3.1.1

# %% [markdown]
# ## UDPipe

# %% [markdown]
# * Помимо этого, нам потребуются языковые синтаксические модели, взятые отсюда https://lindat.mff.cuni.cz/repository/xmlui/handle/11234/1-3131
# * Более конкретно, эту (уже есть в вашей папке data)
# https://lindat.mff.cuni.cz/repository/xmlui/bitstream/handle/11234/1-3131/russian-syntagrus-ud-2.5-191206.udpipe?sequence=70&isAllowed=y

# %%
# Подключаем синтаксической анализатор и его части.
import ufal.udpipe
from ufal.udpipe import Model, Pipeline, ProcessingError

# Для отрисовки деревьев нам потребуются вот эти библиотеки.

from collections import defaultdict
from tqdm.auto import tqdm
import random

# %%
#загружаем модель
model = Model.load('/content/drive/MyDrive/ML ITHUB осень/ДИ 2024/IT-СИП-22-23-DATA-ML/data/Копия файла "russian-syntagrus-ud-2.5-191206.udpipe"')

# %%
# Токенизатор со снятием омонимии.
tokenizer = model.newTokenizer(model.DEFAULT)
# Объект для отображения результатов разбора.
conlluOutput = ufal.udpipe.OutputFormat.newOutputFormat("conllu")
# Объект предложения, в которое будет осуществляться разбор.
sentence = ufal.udpipe.Sentence()
# Объект для ошибок, возникающих в ходе разбора.
error = ufal.udpipe.ProcessingError()

# %%
df['description'][5]
# Out:
# 'Умение разбираться в поставленных задачах, уточнять их условия и результат, выбирать эффективные способы решения. Понимание ООП и паттернов проектирования, следование... Мы работаем над предоставлением нашим клиентам целого комплекса IT-решений, начиная с e-commerce и заканчивая digital-трансформацией традиционной розницы. '

# %%
#кормим токенизатору наш текст
tokenizer.setText(df['description'][5])

# %% [markdown]
# Далее предложение передается на морфологическую разметку со снятием омонимии (тэггинг) и синтаксический анализ (парсинг).
#
# Результаты разбора можно отображать в разных форматах, но мы будем использовать формат conllu.

# %%
tokenizer.nextSentence(sentence, error)
model.tag(sentence, model.DEFAULT)
model.parse(sentence, model.DEFAULT)
print(conlluOutput.writeSentence(sentence))
# Out:
# # newdoc
# # newpar
# # sent_id = 1
# # text = Умение разбираться в поставленных задачах, уточнять их условия и результат, выбирать эффективные способы решения.
# 1	Умение	умение	NOUN	_	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing	0	root	_	_
# 2	разбираться	разбираться	VERB	_	Aspect=Imp|VerbForm=Inf|Voice=Mid	1	obl	_	_
# 3	в	в	ADP	_	_	5	case	_	_
# 4	поставленных	ставить	VERB	_	Aspect=Perf|Case=Loc|Number=Plur|Tense=Past|VerbForm=Part|Voice=Pass	5	amod	_	_
# 5	задачах	задача	NOUN	_	Animacy=Inan|Case=Loc|Gender=Fem|Number=Plur	2	obl	_	SpaceAfter=No
# 6	,	,	PUNCT	_	_	7	punct	_	_
# 7	уточнять	уточнять	VERB	_	Aspect=Imp|VerbForm=Inf|Voice=Act	2	conj	_	_
# 8	их	их	DET	_	_	9	det	_	_
# 9	условия	условие	NOUN	_	Animacy=Inan|Case=Acc|Gender=Neut|Number=Plur	7	obj	_	_
# 10	и	и	CCONJ	_	_	11	cc	_	_
# 11	результат	результат	NOUN	_	Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing	9	conj	_	SpaceAfter=No
# 12	,	,	PUNCT	_	_	13	punct	_	_
# 13	выбирать	выбирать	VERB	_	Aspect=Imp|VerbForm=Inf|Voice=Act	2	conj	_	_
# 14	эффективные	эффективный	ADJ	_	Animacy=Inan|Case=Acc|Degree=Pos|Number=Plur	15	amod	_	_
# 15	способы	способ	NOUN	_	Animacy=Inan|Case=Acc|Gender=Masc|Number=Plur	13	obj	_	_
# 16	решения	решение	NOUN	_	Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing	15	nmod	_	SpaceAfter=No
# 17	.	.	PUNCT	_	_	1	punct	_	_

# %% [markdown]
# Объект Sentence содержит в себе свойство words, являющееся списком слов. Каждое слово включает в себя, среди прочего, следующие свойства:

# %% [markdown]
# * lemma - начальная форма слова,
# * form - токен,
# * head - номер родительского элемента в списке слов,
# * deprel - название отношения,
# * upostag - часть речи,
# * feats - грамматические параметры,
# * misc - дополнительные параметры.

# %%
df_sentence = pd.DataFrame(columns=['head','lemma','form','upostag','feats','deprel','misc'])

# %%
for i, word in enumerate(sentence.words):
  df_sentence.loc[len(df_sentence)] = [word.head, word.lemma, word.form, word.upostag, word.feats, word.deprel, word.misc]
    #print(i, "->", word.head, word.lemma, "[", word.form, "]", word.upostag, word.feats, word.deprel, word.misc)
df_sentence
# Out:
#     head        lemma          form upostag  \
# 0     -1       <root>        <root>  <root>
# 1      0       умение        Умение    NOUN
# 2      1  разбираться   разбираться    VERB
# 3      5            в             в     ADP
# 4      5      ставить  поставленных    VERB
# 5      2       задача       задачах    NOUN
# 6      7            ,             ,   PUNCT
# 7      2     уточнять      уточнять    VERB
# 8      9           их            их     DET
# 9      7      условие       условия    NOUN
# 10    11            и             и   CCONJ
# 11     9    результат     результат    NOUN
# 12    13            ,             ,   PUNCT
# 13     2     выбирать      выбирать    VERB
# 14    15  эффективный   эффективные     ADJ
# 15    13       способ       способы    NOUN
# 16    15      решение       решения    NOUN
# 17     1            .             .   PUNCT
#
#                                                 feats deprel           misc
# 0                                              <root>
# 1       Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing   root
# 2                   Aspect=Imp|VerbForm=Inf|Voice=Mid    obl
# 3                                                       case
# 4   Aspect=Perf|Case=Loc|Number=Plur|Tense=Past|Ve...   amod
# 5        Animacy=Inan|Case=Loc|Gender=Fem|Number=Plur    obl  SpaceAfter=No
# 6                                                      punct
# 7                   Aspect=Imp|VerbForm=Inf|Voice=Act   conj
# 8                                                        det
# 9       Animacy=Inan|Case=Acc|Gender=Neut|Number=Plur    obj
# 10                                                        cc
# 11      Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing   conj  SpaceAfter=No
# 12                                                     punct
# 13                  Aspect=Imp|VerbForm=Inf|Voice=Act   conj
# 14       Animacy=Inan|Case=Acc|Degree=Pos|Number=Plur   amod
# 15      Animacy=Inan|Case=Acc|Gender=Masc|Number=Plur    obj
# 16      Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing   nmod  SpaceAfter=No
# 17                                                     punct

# %% [markdown]
# Давайте возьмем текст и выделим из него все сочетания "существительное + существительное в родительном падеже". Такие сочетания интересны тем, что могут претендовать на роль терминов.

# %%
def find_child_Ng(sentence, parent):
    """ Функция поиска всех потомков вершины с номером parent, являющихся
    существительными в родительном падеже.
    """
    children = []
    for i, word in enumerate(sentence.words):
        if word.head == parent and word.upostag == "NOUN" and "Case=Gen" in word.feats:
            children.append(i)
    return children

def find_NNg(sentence, combinations):
    """ Функция поиска сочетаний "существительное + существительное в родительном падеже".
    """
    for i, word in enumerate(sentence.words):
        if word.upostag == "NOUN":
            children = find_child_Ng(sentence, i)
            if children != []:
                #print(word.lemma, [sentence.words[k].form for k in children])
                for child in children:
                    combinations[word.lemma][sentence.words[child].form] += 1

# %%
combinations = defaultdict(lambda:defaultdict(int))

for text in tqdm(df['description'][:1000]):
    tokenizer.setText(text) # Установить текст.
    while tokenizer.nextSentence(sentence, error): # Полчаем следующее предложение.
        model.tag(sentence, model.DEFAULT) # Токенизация.
        model.parse(sentence, model.DEFAULT) # Синтаксический анализ.
        find_NNg(sentence, combinations) # Поиск сочетаний.
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
combinations['доработка']
# Out:
# defaultdict(int,
#             {'продуктов': 3,
#              'части': 1,
#              'решений': 6,
#              'отчетов': 2,
#              'конфигурации': 18,
#              'функционала': 14,
#              'конфигураций': 36,
#              'ИС': 1,
#              'механизмов': 2,
#              'сайтов': 3,
#              'частей': 1,
#              'программы': 2,
#              'задачи': 1,
#              'продукта': 1,
#              'расширений': 1,
#              'обмена': 1,
#              'интернет-магазина': 1,
#              'банков': 1,
#              'моделей': 1,
#              'сайта': 2,
#              'компонентов': 2,
#              'требования': 3,
#              'подсистем': 3,
#              'функциональности': 4,
#              'модулей': 2,
#              'базы': 1,
#              'системы': 1,
#              'управления': 1,
#              'программ': 3,
#              'решения': 2,
#              'разделов': 1,
#              'возможностей': 1,
#              '1C:': 1,
#              '1с': 1,
#              'систем': 2,
#              'процедур': 1,
#              'объектов': 1,
#              'форм': 1,
#              'функций': 2,
#              'обновления': 1,
#              'сеть»': 1,
#              'проектов': 1,
#              'разработок': 1,
#              'схем': 1,
#              'кода': 1,
#              'работ': 1})

# %%
df_nn=pd.DataFrame(columns=['parent','children','freq'])
for parent, childs in combinations.items():
    for child, freq in childs.items():
        if freq > 20:
            df_nn.loc[len(df_nn)] = [parent, child,freq]

# %%
df_nn.sort_values(by='freq',ascending=False).head(20)
# Out:
#         parent          children  freq
# 5         опыт            работы   404
# 6         опыт        разработки   136
# 24        язык  программирования    73
# 11      знание             языка    65
# 8         опыт  программирования    62
# 26  проведение        тренировок    56
# 22        база            данных    51
# 16  разработка       обеспечения    50
# 10      знание             основ    49
# 2       работа               лет    41
# 0    доработка      конфигураций    36
# 13      знание            языков    34
# 9         опыт               лет    30
# 15  разработка       функционала    29
# 14      знание      конфигураций    28
# 19  разработка          программ    27
# 17  разработка        приложений    25
# 12      знание         платформы    24
# 3    понимание         принципов    24
# 1      решение             задач    23
