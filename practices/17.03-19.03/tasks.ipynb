# %%
import pandas as pd

# %% [markdown]
# ## Данные

# %% [markdown]
# Прогнозируйте признак gamma_GTP (фермент (белок) печени и поджелудочной железы). Активность этого фермента в крови повышается при заболеваниях печени и злоупотреблении алкоголем

# %%
train = pd.read_csv(r'C:\Users\User\Desktop\AI_DL_2025\practices\17.03-19.03\train.csv')
train.head()
# Out:
#       sex  age  height  weight  waistline  sight_left  sight_right  hear_left  \
# 0  Female   45     150      50       70.0         1.0          0.9        1.0
# 1    Male   25     175      65       76.0         1.5          1.5        1.0
# 2    Male   55     160      75       98.0         1.0          0.9        1.0
# 3    Male   55     170      70       87.0         1.0          0.3        1.0
# 4  Female   70     145      55       87.5         0.3          0.1        1.0
#
#    hear_right    SBP  ...  tot_chole  HDL_chole  LDL_chole  triglyceride  \
# 0         1.0  102.0  ...      203.0       77.0       94.0         160.0
# 1         1.0  109.0  ...      133.0       51.0       69.0          65.0
# 2         1.0  124.0  ...      207.0       43.0      137.0         136.0
# 3         1.0  116.0  ...      197.0       39.0      131.0         133.0
# 4         1.0  119.0  ...      150.0       53.0       79.0          91.0
#
#    hemoglobin  urine_protein  serum_creatinine  SGOT_AST  SGOT_ALT  gamma_GTP
# 0        13.5            1.0               0.6      18.0      10.0       20.0
# 1        15.4            1.0               0.9      14.0      11.0       14.0
# 2        14.8            1.0               1.0      39.0      44.0       80.0
# 3        15.7            1.0               1.0      17.0      16.0       17.0
# 4        12.7            4.0               1.1      20.0      12.0       10.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Решаем задачу регрессии - предсказываем значение Gamma_GTP

# %% [markdown]
# ## Задания

# %%
## 1 - обработайте категориальные значения
train['sex']=train['sex'].map({'Female':0,'Male':1})

# %%
## 2 - выделите признаки(X) и результирующую (Y), стандартизируйте признаки, разбейте данные на обучающую, валидационную и тестовую выборки

# %%
from sklearn.preprocessing import StandardScaler
X=train.drop(['gamma_GTP'],axis=1)
Y=train['gamma_GTP']

# %%
scaler = StandardScaler()
scal_X = scaler.fit_transform(X)
scal_X = pd.DataFrame(scal_X, columns=X.columns)

# %%
from sklearn.model_selection import train_test_split
X_train_full,X_test,y_train_full,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)
X_train,X_valid,y_train,y_valid = train_test_split(X_train_full,y_train_full,test_size=0.2,random_state=0)

# %%
## 3 - создайте нейронную сеть с помощью Keras c одним скрытым слоем с 50 нейронами (функция активации - relu), метрика - mse
## обучите сеть

# %%
## 4 - оцените качество модели на тестовой выборке

# %%
## 5 - постройте вторую сеть, где будет уже два скрытых слоя - количество нейронов выбираете сами, обучите модель, оцените качество

# %%
## 6 - постройте график с тремя линиями (реальные значения, предсказанные с помощью 1 модели, предсказанные с помощью 2 модели)

# %%
# для тестового набора данных с помощью вашей модели предскажите значение GammaGTP, метрика для проверки MAE

# %%
test_features = pd.read_csv('/content/test_features.csv')
test_features.head()
# Out:
#       sex  age  height  weight  waistline  sight_left  sight_right  hear_left  \
# 0  Female   45     155      55       73.0         0.8          0.6        1.0
# 1    Male   65     165      65       83.0         0.5          0.5        1.0
# 2    Male   70     165      70       88.0         0.5          0.9        1.0
# 3    Male   50     160      65       87.0         1.0          0.8        1.0
# 4    Male   35     170      65       87.0         1.0          1.0        1.0
#
#    hear_right    SBP  ...   BLDS  tot_chole  HDL_chole  LDL_chole  \
# 0         1.0  107.0  ...  100.0      148.0       56.0       78.0
# 1         1.0  172.0  ...  143.0      209.0       49.0      143.0
# 2         2.0  120.0  ...   83.0      206.0       77.0      112.0
# 3         1.0  142.0  ...   74.0       90.0       33.0       36.0
# 4         1.0  120.0  ...  161.0      255.0       60.0      135.0
#
#    triglyceride  hemoglobin  urine_protein  serum_creatinine  SGOT_AST  \
# 0          69.0         9.3            1.0               0.8      14.0
# 1          84.0        14.1            1.0               0.6      19.0
# 2         116.0        14.6            1.0               0.9      15.0
# 3         103.0        13.9            1.0               0.8      34.0
# 4         298.0        15.8            1.0               0.7      23.0
#
#    SGOT_ALT
# 0       9.0
# 1      19.0
# 2      12.0
# 3      14.0
# 4      28.0
#
# [5 rows x 21 columns]

# %%
y_pred = model.predict(test_features)

# %%
df = pd.DataFrame()
df['result']=y_pred.reshape(-1)
df.to_csv('Фамилия_Группа.csv',index=False)

# %%
# результат прогноза для тестовой выборки просылаем в формате csv,
# где лежит только один столбец result, название файла - Фамилия_Группа.csv
# группа ИБ или БПМ - пример Бимбумбамов_ИБ.csv или Бимбумбамов_БПМ.csv

# %% [markdown]
# ссылка для загрузки файлов -
