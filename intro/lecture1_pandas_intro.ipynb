# %% [markdown]
# # Лекция 1.Введение в pandas

# %%
#импорт библиотек
from IPython.display import Image
import pandas as pd

# %%
#считаем файл с екселем в датафрейм
df=pd.read_excel('/content/moviedb.xlsx')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#вывод датафрейма, head/tail
df.head(10)
# Out:
#    Unnamed: 0                                        title  \
# 0        7495  Пираты Карибского моря: На странных берегах
# 1        6783                              Мстители: Финал
# 2        6308                          Лига справедливости
# 3        6781                Мстители: Война бесконечности
# 4        7494        Пираты Карибского моря: На краю света
# 5       10171                          Лига справедливости
# 6        4659                        Возвращение Супермена
# 7        8031                Рапунцель: Запутанная история
# 8        9265             Человек-паук 3: Враг в отражении
# 9        7160                            Одинокий рейнджер
#
#                release  runtime       budget       revenue lang       genre1  \
# 0  2011-05-14 00:00:00    136.0  380000000.0  1.045714e+09   en  приключения
# 1  2019-04-24 00:00:00    182.0  356000000.0  2.797801e+09   en  приключения
# 2                43054    110.0  300000000.0  6.579243e+08   en       боевик
# 3  2018-04-25 00:00:00    149.0  300000000.0  2.046240e+09   en  приключения
# 4                39221    169.0  300000000.0  9.610000e+08   en  приключения
# 5  2017-11-15 00:00:00    110.0  300000000.0  6.579270e+08   en       боевик
# 6                38896    154.0  270000000.0  3.910812e+08   en   фантастика
# 7                40506    100.0  260000000.0  5.924617e+08   en   мультфильм
# 8                39203    139.0  258000000.0  8.908716e+08   en      фэнтези
# 9                41458    135.0  255000000.0  8.928991e+07   en       боевик
#
#         genre2 country1  ...                         writer  \
# 0       боевик       GB  ...                            NaN
# 1   фантастика       US  ...                 Marvel Studios
# 2  приключения       GB  ...                   Chris Terrio
# 3       боевик       US  ...                 Marvel Studios
# 4      фэнтези       US  ...        Jerry Bruckheimer Films
# 5  приключения       US  ...                            NaN
# 6       боевик       US  ...                      DC Comics
# 7     семейный       US  ...  Walt Disney Animation Studios
# 8       боевик       US  ...              Columbia Pictures
# 9  приключения       US  ...           Walt Disney Pictures
#
#                     studio1                  studio2            keyword1  \
# 0      Walt Disney Pictures  Jerry Bruckheimer Films             england
# 1                       NaN             space travel         time travel
# 2                 DC Comics         DC Entertainment           dc comics
# 3                       NaN                    magic           sacrifice
# 4   Second Mate Productions            exotic island  east india company
# 5      RatPac Entertainment    Cruel & Unusual Films           superhero
# 6        Legendary Pictures         saving the world           dc comics
# 7      Walt Disney Pictures                  hostage               magic
# 8  Laura Ziskin Productions        loss of loved one       dual identity
# 9   Jerry Bruckheimer Films                    texas               horse
#
#              keyword2        keyword3            keyword4  \
# 0               spain             sea             captain
# 1        time machine          sequel      based on comic
# 2           superhero  based on comic         super power
# 3           superhero  based on comic               space
# 4  love of one's life         traitor           shipwreck
# 5      based on comic     super power      superhero team
# 6     invulnerability          sequel           superhero
# 7               horse      fairy tale             musical
# 8             amnesia       sandstorm  love of one's life
# 9            survivor    texas ranger             partner
#
#               keyword5              keyword6    rating
# 0               mutiny                 sword  6.500000
# 1       alien invasion        superhero team  7.873993
# 2       superhero team   aftercreditsstinger  6.307256
# 3          battlefield              genocide  7.963608
# 4         strong woman             singapore  7.200000
# 5  aftercreditsstinger  duringcreditsstinger  6.100000
# 6       based on comic           super power  5.600000
# 7               blonde              princess  7.600000
# 8          forgiveness                spider  6.200000
# 9               outlaw       native american  6.000000
#
# [10 rows x 27 columns]

# %%
df.tail()
# Out:
#        Unnamed: 0                           title              release  \
# 10277       10270  Девушка, которая боялась дождя  2021-02-12 00:00:00
# 10278       10272                      The Father  2021-03-21 00:00:00
# 10279       10277                         Белфаст  2021-11-12 00:00:00
# 10280       10279                    Под гипнозом  2021-10-27 00:00:00
# 10281       10281             Параллельные матери  2021-10-08 00:00:00
#
#        runtime  budget     revenue lang   genre1 genre2 country1  ...  \
# 10277     92.0     NaN         NaN   en  триллер  ужасы       US  ...
# 10278      5.0     NaN         NaN   en    драма    NaN       GB  ...
# 10279     98.0     NaN  30000000.0   en    драма    NaN       GB  ...
# 10280     88.0     NaN         NaN   en  триллер  драма       CA  ...
# 10281    123.0     NaN         NaN   es    драма    NaN       ES  ...
#
#                  writer                  studio1             studio2  \
# 10277   Castille Landon    Pinstripe Productions  Sweet Tomato Films
# 10278      Blake Ridder             Ridder Films                 NaN
# 10279   Kenneth Branagh  Northern Ireland Screen                TKBC
# 10280  Richard D'Ovidio            The Long Game                 NaN
# 10281               NaN                 El Deseo                 TVE
#
#             keyword1         keyword2                keyword3        keyword4  \
# 10277     kidnapping         neighbor                    fear  mental illness
# 10278            NaN              NaN                     NaN             NaN
# 10279  working class  black and white  belfast, north ireland           1960s
# 10280            NaN              NaN                     NaN             NaN
# 10281         mother     photographer       spanish civil war      motherhood
#
#                 keyword5  keyword6 rating
# 10277     hearing voices       NaN    7.2
# 10278                NaN       NaN    0.0
# 10279                NaN       NaN    7.2
# 10280                NaN       NaN    6.1
# 10281  switched at birth  bisexual    6.9
#
# [5 rows x 27 columns]

# %%
Image(url="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQn2sZfCQvOalKr1UucuW_yxfNSz83Wy80YkA&usqp=CAU", height=300, width=500)
# Out:
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQn2sZfCQvOalKr1UucuW_yxfNSz83Wy80YkA&usqp=CAU" width="500" height="300"/>

# %%
#info - информация о датафрейме
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10282 entries, 0 to 10281
# Data columns (total 27 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10282 non-null  int64
#  1   title       10282 non-null  object
#  2   release     10020 non-null  object
#  3   runtime     10130 non-null  float64
#  4   budget      4119 non-null   float64
#  5   revenue     4113 non-null   float64
#  6   lang        8972 non-null   object
#  7   genre1      9322 non-null   object
#  8   genre2      6558 non-null   object
#  9   country1    8748 non-null   object
#  10  country2    2102 non-null   object
#  11  actor1      9277 non-null   object
#  12  actor2      8992 non-null   object
#  13  actor3      8752 non-null   object
#  14  actor4      8539 non-null   object
#  15  actor5      8301 non-null   object
#  16  director    9575 non-null   object
#  17  writer      7052 non-null   object
#  18  studio1     7461 non-null   object
#  19  studio2     6172 non-null   object
#  20  keyword1    7201 non-null   object
#  21  keyword2    6398 non-null   object
#  22  keyword3    5748 non-null   object
#  23  keyword4    5111 non-null   object
#  24  keyword5    4460 non-null   object
#  25  keyword6    3893 non-null   object
#  26  rating      10240 non-null  float64
# dtypes: float64(4), int64(1), object(22)
# memory usage: 2.1+ MB

# %%
#размер датафрейма
df.shape
# Out:
# (10282, 27)

# %%
df['budget']=df['budget']/1000000
df['revenue']=df['revenue']/1000000

# %%
df.head()
# Out:
#    Unnamed: 0                                        title  \
# 0        7495  Пираты Карибского моря: На странных берегах
# 1        6783                              Мстители: Финал
# 2        6308                          Лига справедливости
# 3        6781                Мстители: Война бесконечности
# 4        7494        Пираты Карибского моря: На краю света
#
#                release  runtime  budget      revenue lang       genre1  \
# 0  2011-05-14 00:00:00    136.0   380.0  1045.713802   en  приключения
# 1  2019-04-24 00:00:00    182.0   356.0  2797.800564   en  приключения
# 2                43054    110.0   300.0   657.924295   en       боевик
# 3  2018-04-25 00:00:00    149.0   300.0  2046.239637   en  приключения
# 4                39221    169.0   300.0   961.000000   en  приключения
#
#         genre2 country1  ...                   writer  \
# 0       боевик       GB  ...                      NaN
# 1   фантастика       US  ...           Marvel Studios
# 2  приключения       GB  ...             Chris Terrio
# 3       боевик       US  ...           Marvel Studios
# 4      фэнтези       US  ...  Jerry Bruckheimer Films
#
#                    studio1                  studio2            keyword1  \
# 0     Walt Disney Pictures  Jerry Bruckheimer Films             england
# 1                      NaN             space travel         time travel
# 2                DC Comics         DC Entertainment           dc comics
# 3                      NaN                    magic           sacrifice
# 4  Second Mate Productions            exotic island  east india company
#
#              keyword2        keyword3        keyword4        keyword5  \
# 0               spain             sea         captain          mutiny
# 1        time machine          sequel  based on comic  alien invasion
# 2           superhero  based on comic     super power  superhero team
# 3           superhero  based on comic           space     battlefield
# 4  love of one's life         traitor       shipwreck    strong woman
#
#               keyword6    rating
# 0                sword  6.500000
# 1       superhero team  7.873993
# 2  aftercreditsstinger  6.307256
# 3             genocide  7.963608
# 4            singapore  7.200000
#
# [5 rows x 27 columns]

# %%
#статистика по количественным переменным
df.describe()
# Out:
#          Unnamed: 0       runtime       budget      revenue        rating
# count  10282.000000  10130.000000  4119.000000  4113.000000  10240.000000
# mean    5140.500000     88.593287    39.864067   117.781195      5.181666
# std     2968.302068     40.281324    48.226540   206.444991      2.599802
# min        0.000000      0.000000     0.000001     0.000001      0.000000
# 25%     2570.250000     83.000000     7.500000     9.128263      4.900000
# 50%     5140.500000     96.000000    22.000000    42.664410      6.100000
# 75%     7710.750000    109.000000    52.000000   129.394835      6.800000
# max    10281.000000    840.000000   380.000000  2797.800564     10.000000

# %%
#срез по столбцам - столбцы и iloc
df_new=df[['title','budget','revenue']]
df_new
# Out:
#                                              title  budget      revenue
# 0      Пираты Карибского моря: На странных берегах   380.0  1045.713802
# 1                                  Мстители: Финал   356.0  2797.800564
# 2                              Лига справедливости   300.0   657.924295
# 3                    Мстители: Война бесконечности   300.0  2046.239637
# 4            Пираты Карибского моря: На краю света   300.0   961.000000
# ...                                            ...     ...          ...
# 10277               Девушка, которая боялась дождя     NaN          NaN
# 10278                                   The Father     NaN          NaN
# 10279                                      Белфаст     NaN    30.000000
# 10280                                 Под гипнозом     NaN          NaN
# 10281                          Параллельные матери     NaN          NaN
#
# [10282 rows x 3 columns]

# %%
#срез по строкам
df[100:]
# Out:
#        Unnamed: 0                                           title  \
# 100          8810                                   Тор: Рагнарёк
# 101          9029          Фантастические твари и где они обитают
# 102          9169  Хроники Нарнии: Лев, колдунья и волшебный шкаф
# 103          9835                             Тихоокеанский рубеж
# 104         10116                                     Малефисента
# ...           ...                                             ...
# 10277       10270                  Девушка, которая боялась дождя
# 10278       10272                                      The Father
# 10279       10277                                         Белфаст
# 10280       10279                                    Под гипнозом
# 10281       10281                             Параллельные матери
#
#                    release  runtime       budget      revenue lang  \
# 100                  43033    130.0  180000000.0  853977126.0   en
# 101                  42690    133.0  180000000.0  809342332.0   en
# 102    2005-12-07 00:00:00    143.0  180000000.0  745013115.0   en
# 103    2013-07-11 00:00:00    131.0  180000000.0  407602906.0   en
# 104    2014-05-28 00:00:00     97.0  180000000.0  758539785.0   en
# ...                    ...      ...          ...          ...  ...
# 10277  2021-02-12 00:00:00     92.0          NaN          NaN   en
# 10278  2021-03-21 00:00:00      5.0          NaN          NaN   en
# 10279  2021-11-12 00:00:00     98.0          NaN   30000000.0   en
# 10280  2021-10-27 00:00:00     88.0          NaN          NaN   en
# 10281  2021-10-08 00:00:00    123.0          NaN          NaN   es
#
#             genre1       genre2 country1  ...            writer  \
# 100         боевик  приключения       US  ...        Craig Kyle
# 101    приключения      фэнтези       GB  ...      Heyday Films
# 102    приключения     семейный       GB  ...               NaN
# 103         боевик   фантастика       US  ...               NaN
# 104        фэнтези  приключения       US  ...               NaN
# ...            ...          ...      ...  ...               ...
# 10277      триллер        ужасы       US  ...   Castille Landon
# 10278        драма          NaN       GB  ...      Blake Ridder
# 10279        драма          NaN       GB  ...   Kenneth Branagh
# 10280      триллер        драма       CA  ...  Richard D'Ovidio
# 10281        драма          NaN       ES  ...               NaN
#
#                            studio1               studio2          keyword1  \
# 100                 Marvel Studios  Walt Disney Pictures            sequel
# 101          Warner Bros. Pictures         new york city           robbery
# 102           Walt Disney Pictures          Walden Media  saving the world
# 103    Double Dare You Productions    Legendary Pictures           monster
# 104           Walt Disney Pictures            Roth Films             fairy
# ...                            ...                   ...               ...
# 10277        Pinstripe Productions    Sweet Tomato Films        kidnapping
# 10278                 Ridder Films                   NaN               NaN
# 10279      Northern Ireland Screen                  TKBC     working class
# 10280                The Long Game                   NaN               NaN
# 10281                     El Deseo                   TVE            mother
#
#                    keyword2                keyword3                keyword4  \
# 100               superhero          based on comic            alien planet
# 101                   magic           teleportation                suitcase
# 102    sibling relationship                   witch  based on novel or book
# 103                dystopia                 pacific                  alaska
# 104              fairy tale                 villain         sleeping beauty
# ...                     ...                     ...                     ...
# 10277              neighbor                    fear          mental illness
# 10278                   NaN                     NaN                     NaN
# 10279       black and white  belfast, north ireland                   1960s
# 10280                   NaN                     NaN                     NaN
# 10281          photographer       spanish civil war              motherhood
#
#                 keyword5         keyword6    rating
# 100       female villain  norse mythology  7.769107
# 101             spin off   subway station  7.400000
# 102       self sacrifice           winter  7.100000
# 103          giant robot    giant monster  6.800000
# 104             betrayal            curse  7.100000
# ...                  ...              ...       ...
# 10277     hearing voices              NaN  7.200000
# 10278                NaN              NaN  0.000000
# 10279                NaN              NaN  7.200000
# 10280                NaN              NaN  6.100000
# 10281  switched at birth         bisexual  6.900000
#
# [10182 rows x 27 columns]

# %%
#подсчет значений - value_counts
df['genre1'].value_counts()
# Out:
# драма                  2174
# комедия                1824
# боевик                 1124
# документальный          690
# приключения             520
# ужасы                   505
# мультфильм              423
# триллер                 393
# криминал                379
# музыка                  214
# фэнтези                 212
# мелодрама               187
# семейный                175
# фантастика              165
# вестерн                  97
# детектив                 87
# военный                  71
# история                  49
# телевизионный фильм      33
# Name: genre1, dtype: int64

# %% [markdown]
# ## Сортировка

# %%
#сортировка
df.sort_values(by='revenue',ascending=False).head(10)
# Out:
#      Unnamed: 0                                        title  \
# 1          6783                              Мстители: Финал
# 26         3950                                       Аватар
# 25         5589  Звёздные войны: Эпизод 7 - Пробуждение силы
# 3          6781                Мстители: Война бесконечности
# 67         9869                 Человек-паук: Нет пути домой
# 202        6629                          Мир Юрского периода
# 31         6780                                     Мстители
# 82         9072                                     Форсаж 7
# 16         6784                       Мстители: Эра Альтрона
# 62         9351                               Чёрная Пантера
#
#                  release  runtime  budget      revenue lang       genre1  \
# 1    2019-04-24 00:00:00    182.0   356.0  2797.800564   en  приключения
# 26   2009-12-10 00:00:00    162.0   237.0  2787.965087   en       боевик
# 25                 42353    135.0   245.0  2068.223624   en       боевик
# 3    2018-04-25 00:00:00    149.0   300.0  2046.239637   en  приключения
# 67   2021-12-15 00:00:00    148.0   200.0  1888.000000   en       боевик
# 202                42161    124.0   150.0  1671.713208   en       боевик
# 31                 41024    137.0   220.0  1518.815515   en   фантастика
# 82                 42095    137.0   190.0  1515.047671   en       боевик
# 16   2015-04-22 00:00:00    141.0   250.0  1405.403694   en       боевик
# 62   2018-02-13 00:00:00    134.0   200.0  1346.739107   en       боевик
#
#           genre2 country1  ...                writer  \
# 1     фантастика       US  ...        Marvel Studios
# 26   приключения       US  ...         James Cameron
# 25   приключения       US  ...         Michael Arndt
# 3         боевик       US  ...        Marvel Studios
# 67   приключения       US  ...         Chris McKenna
# 202  приключения       US  ...  Amblin Entertainment
# 31        боевик       US  ...        Marvel Studios
# 82       триллер       US  ...          Chris Morgan
# 16   приключения       US  ...           Joss Whedon
# 62   приключения       US  ...        Marvel Studios
#
#                        studio1                   studio2  \
# 1                          NaN              space travel
# 26          Dune Entertainment  Lightstorm Entertainment
# 25              Lucasfilm Ltd.                 Bad Robot
# 3                          NaN                     magic
# 67              Marvel Studios           Pascal Pictures
# 202         Legendary Pictures                       dna
# 31                   Paramount             new york city
# 82   Abu Dhabi Film Commission        Universal Pictures
# 16              Marvel Studios                       NaN
# 62        Walt Disney Pictures                    africa
#
#                     keyword1            keyword2             keyword3  \
# 1                time travel        time machine               sequel
# 26             culture clash              future            space war
# 25                   android          spacecraft                 jedi
# 3                  sacrifice           superhero       based on comic
# 67             new york city   loss of loved one             showdown
# 202        tyrannosaurus rex        velociraptor               island
# 31                    shield           superhero       based on comic
# 82                  car race               speed          street race
# 16   artificial intelligence  seoul, south korea               sequel
# 62                 superhero      based on comic  aftercreditsstinger
#
#                  keyword4                   keyword5             keyword6  \
# 1          based on comic             alien invasion       superhero team
# 26           space colony                    society         space travel
# 25            space opera                        NaN                  NaN
# 3                   space                battlefield             genocide
# 67        secret identity                       hero                magic
# 202         animal attack                primal fear               sequel
# 31         alien invasion             superhero team  aftercreditsstinger
# 82                revenge                        car                 race
# 16              superhero             based on comic       superhero team
# 62   duringcreditsstinger  marvel cinematic universe                  NaN
#
#        rating
# 1    7.873993
# 26   8.032663
# 25        NaN
# 3    7.963608
# 67   8.200000
# 202  6.600000
# 31   7.948155
# 82   7.300000
# 16   7.137791
# 62   6.387909
#
# [10 rows x 27 columns]

# %% [markdown]
# ## Фильтрация

# %%
#обычная фильтрация
df_new=df[df['rating']>7]
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1894 entries, 1 to 10279
# Data columns (total 27 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1894 non-null   int64
#  1   title       1894 non-null   object
#  2   release     1875 non-null   object
#  3   runtime     1885 non-null   float64
#  4   budget      984 non-null    float64
#  5   revenue     1042 non-null   float64
#  6   lang        1782 non-null   object
#  7   genre1      1824 non-null   object
#  8   genre2      1371 non-null   object
#  9   country1    1736 non-null   object
#  10  country2    491 non-null    object
#  11  actor1      1819 non-null   object
#  12  actor2      1770 non-null   object
#  13  actor3      1737 non-null   object
#  14  actor4      1714 non-null   object
#  15  actor5      1682 non-null   object
#  16  director    1810 non-null   object
#  17  writer      1438 non-null   object
#  18  studio1     1521 non-null   object
#  19  studio2     1400 non-null   object
#  20  keyword1    1588 non-null   object
#  21  keyword2    1487 non-null   object
#  22  keyword3    1388 non-null   object
#  23  keyword4    1301 non-null   object
#  24  keyword5    1209 non-null   object
#  25  keyword6    1115 non-null   object
#  26  rating      1894 non-null   float64
# dtypes: float64(4), int64(1), object(22)
# memory usage: 414.3+ KB

# %%
df_new.head()
# Out:
#     Unnamed: 0                                  title              release  \
# 1         6783                        Мстители: Финал  2019-04-24 00:00:00
# 3         6781          Мстители: Война бесконечности  2018-04-25 00:00:00
# 4         7494  Пираты Карибского моря: На краю света                39221
# 7         8031          Рапунцель: Запутанная история                40506
# 11        4837    Гарри Поттер и Дары смерти: Часть 1                40468
#
#     runtime  budget      revenue lang       genre1      genre2 country1  ...  \
# 1     182.0   356.0  2797.800564   en  приключения  фантастика       US  ...
# 3     149.0   300.0  2046.239637   en  приключения      боевик       US  ...
# 4     169.0   300.0   961.000000   en  приключения     фэнтези       US  ...
# 7     100.0   260.0   592.461732   en   мультфильм    семейный       US  ...
# 11    146.0   250.0   954.305868   en  приключения     фэнтези       GB  ...
#
#                            writer                  studio1        studio2  \
# 1                  Marvel Studios                      NaN   space travel
# 3                  Marvel Studios                      NaN          magic
# 4         Jerry Bruckheimer Films  Second Mate Productions  exotic island
# 7   Walt Disney Animation Studios     Walt Disney Pictures        hostage
# 11          Warner Bros. Pictures             Heyday Films     corruption
#
#               keyword1            keyword2        keyword3        keyword4  \
# 1          time travel        time machine          sequel  based on comic
# 3            sacrifice           superhero  based on comic           space
# 4   east india company  love of one's life         traitor       shipwreck
# 7                magic               horse      fairy tale         musical
# 11           isolation               radio           magic   teleportation
#
#           keyword5        keyword6    rating
# 1   alien invasion  superhero team  7.873993
# 3      battlefield        genocide  7.963608
# 4     strong woman       singapore  7.200000
# 7           blonde        princess  7.600000
# 11         bravery         tension  7.800000
#
# [5 rows x 27 columns]

# %%
#множественная фильтрация

# %%
#фильтрация через query
df.query('genre1=="драма" and rating>7')
# Out:
#        Unnamed: 0                                  title              release  \
# 88           8908                          Тёмный рыцарь  2008-07-14 00:00:00
# 194          5491  Загадочная история Бенджамина Баттона                39807
# 210          7528                 Планета обезьян: Война                42927
# 229          9512                            Я - легенда                39428
# 263          7725                      Последний самурай                37630
# ...           ...                                    ...                  ...
# 10257       10245                                  Грязь  2019-03-22 00:00:00
# 10262       10252                           Грехопадение  2020-01-17 00:00:00
# 10270       10260                                 Банкир  2020-03-06 00:00:00
# 10275       10265                                 Палмер  2021-01-29 00:00:00
# 10279       10277                                Белфаст  2021-11-12 00:00:00
#
#        runtime  budget      revenue lang genre1      genre2 country1  ...  \
# 88       152.0   185.0  1004.558444   en  драма      боевик       GB  ...
# 194      166.0   150.0   333.932083   en  драма     фэнтези       US  ...
# 210      140.0   150.0   488.533726   en  драма  фантастика       CA  ...
# 229       96.0   150.0   585.410052   en  драма  фантастика       US  ...
# 263      154.0   140.0   456.758981   en  драма      боевик       JP  ...
# ...        ...     ...          ...  ...    ...         ...      ...  ...
# 10257    108.0     NaN          NaN   en  драма      музыка       US  ...
# 10262    115.0     NaN          NaN   en  драма     фэнтези       US  ...
# 10270    120.0     NaN          NaN   en  драма         NaN       US  ...
# 10275    110.0     NaN          NaN   en  драма         NaN       US  ...
# 10279     98.0     NaN    30.000000   en  драма         NaN       GB  ...
#
#                           writer                    studio1  \
# 88                           NaN                  DC Comics
# 194                    Paramount      Warner Bros. Pictures
# 210             20th Century Fox          TSG Entertainment
# 229    Village Roadshow Pictures         Weed Road Pictures
# 263        Warner Bros. Pictures  Bedford Falls Productions
# ...                          ...                        ...
# 10257                Rich Wilkes  10th Street Entertainment
# 10262                Tyler Perry        Tyler Perry Studios
# 10270               George Nolfi      Romulus Entertainment
# 10275           Cheryl Guerriero                  SK Global
# 10279            Kenneth Branagh    Northern Ireland Screen
#
#                            studio2           keyword1           keyword2  \
# 88              Legendary Pictures          dc comics      crime fighter
# 194                          diary               navy            funeral
# 210         based on novel or book             sequel   anthropomorphism
# 229               saving the world      new york city  lost civilisation
# 263                          japan  loss of loved one         war crimes
# ...                            ...                ...                ...
# 10257                    LBI Media                NaN                NaN
# 10262                          NaN                NaN                NaN
# 10270              Hyphenate Films             banker            banking
# 10275  Sidney Kimmel Entertainment                NaN                NaN
# 10279                         TKBC      working class    black and white
#
#                       keyword3   keyword4                 keyword5  \
# 88             secret identity  anti hero                scarecrow
# 194                        tea     travel                 hospital
# 210                        ape        NaN                      NaN
# 229    post-apocalyptic future   dystopia                infection
# 263             sense of guilt  swordplay                  general
# ...                        ...        ...                      ...
# 10257                      NaN        NaN                      NaN
# 10262                      NaN        NaN                      NaN
# 10270      based on true story     racism  los angeles, california
# 10275                      NaN        NaN                      NaN
# 10279   belfast, north ireland      1960s                      NaN
#
#                        keyword6 rating
# 88                       sadism    8.5
# 194        based on short story    7.6
# 210                         NaN    7.1
# 229    matter of life and death    7.2
# 263                     samurai    7.5
# ...                         ...    ...
# 10257                       NaN    7.5
# 10262                       NaN    7.1
# 10270                     1950s    7.5
# 10275                       NaN    8.1
# 10279                       NaN    7.2
#
# [608 rows x 27 columns]

# %%
filtered_df = df[(df['genre1'] == 'драма') & (df['rating'] > 7)]
filtered_df

# %% [markdown]
# ## Задачи

# %%
#задача - оставить в датафрейме фильмы только из России и вывести количество фильмов

# %%
#задача - оставить в датафрейме фильмы топ-5 популярных жанров и вывести топ-20 фильмов по сборам (в помощь isin и loc)

# %%
#задача - вывести топ-5 популярных режиссеров, у которых рейтинг фильма>7

# %%
#задача - создать новый столбец profit в датафрейме (разность сборов и бюджета). Вывести топ-10 фильмов по окупаемости(profit)
